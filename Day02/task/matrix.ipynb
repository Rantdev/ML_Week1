# %%
import numpy as np
student=[[1,2,3],[54,50,55]]
total=0
average=0
print(np.matrix(student))
"""for i in range (2):
    for j in range (3):
        print(student[i][j])
    print("\n")"""
for i in range (3):
    total=total +student[1][i]
    

print("total is ",total,"\n average is ",total/3)
# Out:
# [[ 1  2  3]
#  [54 50 55]]
# total is  159
#  average is  53.0
