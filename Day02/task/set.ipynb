# %%
allstudent={"a","b","c","d","e","f"}
football ={"b","c","a"}
cricket ={"e","a"}
both=football & cricket
onlyone=football^cricket 
none=allstudent-(both|onlyone)
print(both)
print(onlyone)
print(none)
# Out:
# {'a'}
# {'b', 'c', 'e'}
# {'d', 'f'}
