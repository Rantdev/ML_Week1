# %%
Name=input("enter the name")
Age=input("enter the age")
Location=input("enter the location")
Interest=input("Enter the your interest")
print(f'name={Name} \n age={Age} \n location={Location} \n interest={Interest}')
