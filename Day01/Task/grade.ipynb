# %%
i=int(input("Enter the marks 0-100"))
if i>=80:
    print("A")
elif i>=60 and i<80:
    print("B")
elif i>=50 and i<60:
    print("C")
elif i>=40 and i<50:
    print("D")
else:
    print("Fail")
# Out:
# Enter the marks 0-100 33
# Fail
