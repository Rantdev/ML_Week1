# %%
sum=0
l=[]
for i in range(5):
    l.append(float(input(f'enter the temperature {i+1}')))
    sum=sum+l[i]
print(f'Average temperature {sum/5}')
# Out:
# enter the temperature 1 25.3
# enter the temperature 2 26.4
# enter the temperature 3 42.6
# enter the temperature 4 38.9
# enter the temperature 5 45.2
# Average temperature 35.68000000000001
