# %%
import random
n=random.randint(1,100)
for i in range(5):
    e=int(input("Enter the number"))
    if n==e:
        print("Right")
        print(f'the guess number is {n}')
        break
    elif i==4:
        print("all invalid input")
        print(f'the guess number is {n}')
    else:
         print("invalid input")
         continue
# Out:
# Enter the number 34
# invalid input
# Enter the number 33
# invalid input
# Enter the number 66
# invalid input
# Enter the number 99
# invalid input
# Enter the number 54
# all invalid input
# the guess number is 53
